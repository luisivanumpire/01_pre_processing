# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('personas.txt')

people = pd.DataFrame(data)
people
# Out:
#          altura        peso       ingreso  horas_trabajadas  ausencias
# 0    134.433878   70.617864   9973.577534         40.905476          4
# 1    167.158746  109.268295   8961.047249         41.576483          4
# 2    141.480812   81.034644   7437.977263         41.369239          5
# 3    123.227119   57.884172  12064.915290         41.537211          3
# 4    143.554951   93.581093   9296.396167         40.441203          4
# ..          ...         ...           ...               ...        ...
# 995  169.059462  109.612155   9998.522402         41.110352          4
# 996  151.873081   91.697127   6867.097603         40.617061          5
# 997  131.156800   78.301155   9757.539280         40.798085          4
# 998  156.454396   94.163603  11044.031510         41.443604          3
# 999  149.558353   87.134622  13222.253800         41.402637          2
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### The relation between high (altura) and weight (peso)

# %%
plt.scatter(people["altura"], people["peso"])
plt.xlabel("High (cm)")
plt.ylabel("Weight (kg)")
plt.show()

# %% [markdown]
# There is a lineal relation

# %% [markdown]
# ### Relation between income and working hours

# %%
plt.scatter(people["horas_trabajadas"], people["ingreso"])
plt.xlabel("Working hours (Hr)")
plt.ylabel("Income ($)")
plt.show()

# %% [markdown]
# ### Relation between income and absence

# %%
plt.scatter(people["ausencias"], people["ingreso"])
plt.xlabel("Absence (days)")
plt.ylabel("Income ($)")
plt.show()

# %% [markdown]
# There is a negative relation. The graph is a little rare, because we are using a continuous var and a discrete var.

# %% [markdown]
# ### Relation between income and weight

# %%
plt.scatter(people["peso"], people["ingreso"])
plt.xlabel("Weight (Kg)")
plt.ylabel("Income ($)")
plt.show()

# %% [markdown]
# There are not relation between income and weight

# %% [markdown]
# ### Correlation matrix

# %%
people.corr()
# Out:
#                     altura      peso   ingreso  horas_trabajadas  ausencias
# altura            1.000000  0.930608 -0.025283          0.008547   0.025587
# peso              0.930608  1.000000 -0.029852         -0.002483   0.027450
# ingreso          -0.025283 -0.029852  1.000000          0.625514  -0.973104
# horas_trabajadas  0.008547 -0.002483  0.625514          1.000000  -0.603870
# ausencias         0.025587  0.027450 -0.973104         -0.603870   1.000000

# %%
corr_matrix = people.corr()
plt.matshow(corr_matrix, cmap="bwr", vmin=-1, vmax=1) # bwr -1 0 +1
plt.xticks(range(5), people.columns, rotation=90)
plt.yticks(range(5), people.columns)
plt.colorbar()
plt.show()

# %%
corr_matrix = people.corr()
plt.matshow(corr_matrix, cmap="bwr", vmin=-1, vmax=1) # bwr -1 0 +1
plt.xticks(range(5), people.columns, rotation=90)
plt.yticks(range(5), people.columns)

for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        plt.text(i,j,round(corr_matrix.iloc[i,j],2),
                ha="center", va="center")

plt.colorbar()
plt.show()
